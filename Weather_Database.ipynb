# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []


# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 754

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c1f66e5d29204ed32de1bd52c26b0ba1

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | wake forest
# Processing Record 2 of Set 1 | marsh harbour
# Processing Record 3 of Set 1 | atbasar
# Processing Record 4 of Set 1 | chifeng
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | gallup
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | yulara
# Processing Record 12 of Set 1 | nicoya
# Processing Record 13 of Set 1 | abha
# Processing Record 14 of Set 1 | san ramon
# Processing Record 15 of Set 1 | bengkulu
# Processing Record 16 of Set 1 | kokopo
# Processing Record 17 of Set 1 | beloha
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | jiwani
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | biliran
# Processing Record 23 of Set 1 | faanui
# Processing Record 24 of Set 1 | riyadh
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | gaomi
# Processing Record 27 of Set 1 | altamira
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | flinders
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | longyearbyen
# Processing Record 33 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 1 | aklavik
# Processing Record 35 of Set 1 | san jose
# Processing Record 36 of Set 1 | myitkyina
# Processing Record 37 of Set 1 | mbanza-ngungu
# Processing Record 38 of Set 1 | chuy
# Processing Record 39 of Set 1 | richards bay
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 1 | qasigiannguit
# Processing Record 45 of Set 1 | parambu
# Processing Record 46 of Set 1 | petrivka
# Processing Record 47 of Set 1 | republic
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | rikitea
# Processing Record 50 of Set 1 | vao
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | valparaiso
# Processing Record 3 of Set 2 | jardim
# Processing Record 4 of Set 2 | reykjavik
# Processing Record 5 of Set 2 | lebu
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | puerto ayora
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | sokoni
# Processing Record 10 of Set 2 | saint-philippe
# Processing Record 11 of Set 2 | qui nhon
# Processing Record 12 of Set 2 | seoul
# Processing Record 13 of Set 2 | maniitsoq
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | araouane
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | kango
# Processing Record 20 of Set 2 | san patricio
# Processing Record 21 of Set 2 | rutland
# Processing Record 22 of Set 2 | sijunjung
# Processing Record 23 of Set 2 | luanda
# Processing Record 24 of Set 2 | bethel
# Processing Record 25 of Set 2 | katangli
# Processing Record 26 of Set 2 | pevek
# Processing Record 27 of Set 2 | matay
# Processing Record 28 of Set 2 | saskylakh
# Processing Record 29 of Set 2 | carnarvon
# Processing Record 30 of Set 2 | saint george
# Processing Record 31 of Set 2 | caxito
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | te anau
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | mount gambier
# Processing Record 36 of Set 2 | rochegda
# Processing Record 37 of Set 2 | cape town
# Processing Record 38 of Set 2 | sangin
# Processing Record 39 of Set 2 | port macquarie
# Processing Record 40 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 2 | kaitangata
# Processing Record 42 of Set 2 | anito
# Processing Record 43 of Set 2 | ixtapa
# Processing Record 44 of Set 2 | tuktoyaktuk
# Processing Record 45 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 2 | busselton
# Processing Record 47 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 2 | ponta do sol
# Processing Record 49 of Set 2 | otjimbingwe
# Processing Record 50 of Set 2 | manyana
# Processing Record 1 of Set 3 | malazgirt
# Processing Record 2 of Set 3 | batagay-alyta
# Processing Record 3 of Set 3 | husavik
# Processing Record 4 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 3 | ayutla
# Processing Record 6 of Set 3 | north bend
# Processing Record 7 of Set 3 | sao joao da barra
# Processing Record 8 of Set 3 | geraldton
# Processing Record 9 of Set 3 | hobart
# Processing Record 10 of Set 3 | chipinge
# Processing Record 11 of Set 3 | pelym
# Processing Record 12 of Set 3 | port hardy
# Processing Record 13 of Set 3 | nikolskoye
# Processing Record 14 of Set 3 | saint-joseph
# Processing Record 15 of Set 3 | arraial do cabo
# Processing Record 16 of Set 3 | bar harbor
# Processing Record 17 of Set 3 | mahebourg
# Processing Record 18 of Set 3 | bainbridge
# Processing Record 19 of Set 3 | saint-pierre
# Processing Record 20 of Set 3 | basco
# Processing Record 21 of Set 3 | yeniseysk
# Processing Record 22 of Set 3 | waitati
# Processing Record 23 of Set 3 | mani
# Processing Record 24 of Set 3 | lagoa
# Processing Record 25 of Set 3 | anloga
# Processing Record 26 of Set 3 | jawhar
# Processing Record 27 of Set 3 | ahipara
# Processing Record 28 of Set 3 | severo-kurilsk
# Processing Record 29 of Set 3 | isangel
# Processing Record 30 of Set 3 | gloversville
# Processing Record 31 of Set 3 | coihaique
# Processing Record 32 of Set 3 | merauke
# Processing Record 33 of Set 3 | ruwi
# Processing Record 34 of Set 3 | cayenne
# Processing Record 35 of Set 3 | ilulissat
# Processing Record 36 of Set 3 | davila
# Processing Record 37 of Set 3 | victoria
# Processing Record 38 of Set 3 | talnakh
# Processing Record 39 of Set 3 | nome
# Processing Record 40 of Set 3 | pontes e lacerda
# Processing Record 41 of Set 3 | muros
# Processing Record 42 of Set 3 | kuala kedah
# Processing Record 43 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 3 | umm lajj
# Processing Record 45 of Set 3 | agirish
# Processing Record 46 of Set 3 | ahuimanu
# Processing Record 47 of Set 3 | marienburg
# Processing Record 48 of Set 3 | reforma
# Processing Record 49 of Set 3 | beipiao
# Processing Record 50 of Set 3 | roald
# Processing Record 1 of Set 4 | sabha
# Processing Record 2 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 4 | alugan
# Processing Record 4 of Set 4 | ontario
# Processing Record 5 of Set 4 | fort nelson
# Processing Record 6 of Set 4 | khatanga
# Processing Record 7 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 8 of Set 4 | yellowknife
# Processing Record 9 of Set 4 | sao miguel do araguaia
# Processing Record 10 of Set 4 | nishihara
# Processing Record 11 of Set 4 | dingle
# Processing Record 12 of Set 4 | tommot
# Processing Record 13 of Set 4 | thayetmyo
# Processing Record 14 of Set 4 | lulea
# Processing Record 15 of Set 4 | makakilo city
# Processing Record 16 of Set 4 | alberton
# Processing Record 17 of Set 4 | port alfred
# Processing Record 18 of Set 4 | cabo san lucas
# Processing Record 19 of Set 4 | pyinmana
# Processing Record 20 of Set 4 | harper
# Processing Record 21 of Set 4 | ksenyevka
# City not found. Skipping...
# Processing Record 22 of Set 4 | maxixe
# Processing Record 23 of Set 4 | placido de castro
# Processing Record 24 of Set 4 | lewistown
# Processing Record 25 of Set 4 | provideniya
# Processing Record 26 of Set 4 | kandrian
# Processing Record 27 of Set 4 | aswan
# Processing Record 28 of Set 4 | barkhan
# Processing Record 29 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 4 | lorengau
# Processing Record 31 of Set 4 | nizwa
# Processing Record 32 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 4 | lipin bor
# Processing Record 34 of Set 4 | sobolevo
# Processing Record 35 of Set 4 | miraflores
# Processing Record 36 of Set 4 | klaksvik
# Processing Record 37 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 4 | burica
# City not found. Skipping...
# Processing Record 39 of Set 4 | ingham
# Processing Record 40 of Set 4 | ribeira grande
# Processing Record 41 of Set 4 | la paz
# Processing Record 42 of Set 4 | laguna
# Processing Record 43 of Set 4 | tulum
# Processing Record 44 of Set 4 | tiksi
# Processing Record 45 of Set 4 | tual
# Processing Record 46 of Set 4 | mangan
# Processing Record 47 of Set 4 | mana
# Processing Record 48 of Set 4 | kavaratti
# Processing Record 49 of Set 4 | vila velha
# Processing Record 50 of Set 4 | lumeje
# Processing Record 1 of Set 5 | esperance
# Processing Record 2 of Set 5 | olafsvik
# Processing Record 3 of Set 5 | manono
# Processing Record 4 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 5 | sao sebastiao
# Processing Record 6 of Set 5 | katsuura
# Processing Record 7 of Set 5 | lavrentiya
# Processing Record 8 of Set 5 | sainte-marie
# Processing Record 9 of Set 5 | khorramshahr
# Processing Record 10 of Set 5 | sambava
# Processing Record 11 of Set 5 | capitan bado
# Processing Record 12 of Set 5 | henties bay
# Processing Record 13 of Set 5 | brae
# Processing Record 14 of Set 5 | okhotsk
# Processing Record 15 of Set 5 | hobyo
# Processing Record 16 of Set 5 | ginir
# Processing Record 17 of Set 5 | agua prieta
# Processing Record 18 of Set 5 | lasa
# Processing Record 19 of Set 5 | ancud
# Processing Record 20 of Set 5 | avarua
# Processing Record 21 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 22 of Set 5 | yuanping
# Processing Record 23 of Set 5 | cherskiy
# Processing Record 24 of Set 5 | palauig
# Processing Record 25 of Set 5 | orchard homes
# Processing Record 26 of Set 5 | hermanus
# Processing Record 27 of Set 5 | hasaki
# Processing Record 28 of Set 5 | tilichiki
# Processing Record 29 of Set 5 | valdivia
# Processing Record 30 of Set 5 | santarem
# Processing Record 31 of Set 5 | tezu
# Processing Record 32 of Set 5 | taoudenni
# Processing Record 33 of Set 5 | grand gaube
# Processing Record 34 of Set 5 | pakxe
# Processing Record 35 of Set 5 | cidreira
# Processing Record 36 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 37 of Set 5 | catarman
# Processing Record 38 of Set 5 | kavieng
# Processing Record 39 of Set 5 | mattru
# Processing Record 40 of Set 5 | alamosa
# Processing Record 41 of Set 5 | broken hill
# Processing Record 42 of Set 5 | conakry
# Processing Record 43 of Set 5 | lucapa
# Processing Record 44 of Set 5 | los llanos de aridane
# Processing Record 45 of Set 5 | tura
# Processing Record 46 of Set 5 | iqaluit
# Processing Record 47 of Set 5 | the valley
# Processing Record 48 of Set 5 | yashkul
# Processing Record 49 of Set 5 | yenangyaung
# Processing Record 50 of Set 5 | kruisfontein
# Processing Record 1 of Set 6 | guerrero negro
# Processing Record 2 of Set 6 | tabou
# Processing Record 3 of Set 6 | bathsheba
# Processing Record 4 of Set 6 | margate
# Processing Record 5 of Set 6 | kungurtug
# Processing Record 6 of Set 6 | liepaja
# Processing Record 7 of Set 6 | tasiilaq
# Processing Record 8 of Set 6 | den helder
# Processing Record 9 of Set 6 | sao gabriel da cachoeira
# Processing Record 10 of Set 6 | bonavista
# Processing Record 11 of Set 6 | hay river
# Processing Record 12 of Set 6 | yar-sale
# Processing Record 13 of Set 6 | sungaipenuh
# Processing Record 14 of Set 6 | jacqueville
# Processing Record 15 of Set 6 | auki
# Processing Record 16 of Set 6 | kutum
# Processing Record 17 of Set 6 | chara
# Processing Record 18 of Set 6 | leningradskiy
# Processing Record 19 of Set 6 | bambous virieux
# Processing Record 20 of Set 6 | bindura
# Processing Record 21 of Set 6 | hukuntsi
# Processing Record 22 of Set 6 | narsaq
# Processing Record 23 of Set 6 | uvarovka
# Processing Record 24 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 6 | menongue
# Processing Record 26 of Set 6 | kroya
# Processing Record 27 of Set 6 | malinovoye ozero
# Processing Record 28 of Set 6 | kupang
# Processing Record 29 of Set 6 | liverpool
# Processing Record 30 of Set 6 | suao
# City not found. Skipping...
# Processing Record 31 of Set 6 | quatre cocos
# Processing Record 32 of Set 6 | itaituba
# Processing Record 33 of Set 6 | kodiak
# Processing Record 34 of Set 6 | roebourne
# Processing Record 35 of Set 6 | hamilton
# Processing Record 36 of Set 6 | porlamar
# Processing Record 37 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 6 | northam
# Processing Record 39 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 6 | clyde river
# Processing Record 41 of Set 6 | findlay
# Processing Record 42 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 44 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 6 | arcata
# Processing Record 46 of Set 6 | sokolo
# Processing Record 47 of Set 6 | mar del plata
# Processing Record 48 of Set 6 | khash
# Processing Record 49 of Set 6 | odweyne
# Processing Record 50 of Set 6 | austin
# Processing Record 1 of Set 7 | gannan
# Processing Record 2 of Set 7 | baykit
# Processing Record 3 of Set 7 | lagunas
# Processing Record 4 of Set 7 | kahului
# Processing Record 5 of Set 7 | mollendo
# Processing Record 6 of Set 7 | port blair
# Processing Record 7 of Set 7 | narasannapeta
# Processing Record 8 of Set 7 | lenine
# Processing Record 9 of Set 7 | kabompo
# Processing Record 10 of Set 7 | avera
# Processing Record 11 of Set 7 | deputatskiy
# Processing Record 12 of Set 7 | alofi
# Processing Record 13 of Set 7 | waipawa
# Processing Record 14 of Set 7 | hearst
# Processing Record 15 of Set 7 | makat
# Processing Record 16 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 7 | hitiaa
# Processing Record 18 of Set 7 | tshela
# Processing Record 19 of Set 7 | manavalakurichi
# Processing Record 20 of Set 7 | okha
# Processing Record 21 of Set 7 | skovorodino
# Processing Record 22 of Set 7 | tashtagol
# Processing Record 23 of Set 7 | coquimbo
# Processing Record 24 of Set 7 | anadyr
# Processing Record 25 of Set 7 | thompson
# Processing Record 26 of Set 7 | ngunguru
# Processing Record 27 of Set 7 | saint anthony
# Processing Record 28 of Set 7 | tulsipur
# Processing Record 29 of Set 7 | pedernales
# Processing Record 30 of Set 7 | manuk mangkaw
# Processing Record 31 of Set 7 | ostrovnoy
# Processing Record 32 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 7 | biak
# Processing Record 34 of Set 7 | santa cruz del norte
# Processing Record 35 of Set 7 | marzuq
# Processing Record 36 of Set 7 | nemuro
# Processing Record 37 of Set 7 | milas
# Processing Record 38 of Set 7 | savannah bight
# Processing Record 39 of Set 7 | ambon
# Processing Record 40 of Set 7 | vardo
# Processing Record 41 of Set 7 | saposoa
# Processing Record 42 of Set 7 | gat
# Processing Record 43 of Set 7 | pimentel
# Processing Record 44 of Set 7 | pangnirtung
# Processing Record 45 of Set 7 | trat
# Processing Record 46 of Set 7 | akdepe
# Processing Record 47 of Set 7 | boyolangu
# Processing Record 48 of Set 7 | poya
# Processing Record 49 of Set 7 | mangrol
# Processing Record 50 of Set 7 | dzheguta
# Processing Record 1 of Set 8 | beringovskiy
# Processing Record 2 of Set 8 | pochutla
# Processing Record 3 of Set 8 | monrovia
# Processing Record 4 of Set 8 | shenxian
# Processing Record 5 of Set 8 | san quintin
# Processing Record 6 of Set 8 | mayumba
# Processing Record 7 of Set 8 | berlevag
# Processing Record 8 of Set 8 | artvin
# Processing Record 9 of Set 8 | shouguang
# Processing Record 10 of Set 8 | marquard
# Processing Record 11 of Set 8 | tuatapere
# Processing Record 12 of Set 8 | souillac
# Processing Record 13 of Set 8 | dali
# Processing Record 14 of Set 8 | tarko-sale
# Processing Record 15 of Set 8 | norman wells
# Processing Record 16 of Set 8 | sao filipe
# Processing Record 17 of Set 8 | port augusta
# Processing Record 18 of Set 8 | xining
# Processing Record 19 of Set 8 | padang
# Processing Record 20 of Set 8 | grindavik
# Processing Record 21 of Set 8 | kaabong
# Processing Record 22 of Set 8 | teknaf
# Processing Record 23 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 24 of Set 8 | otane
# Processing Record 25 of Set 8 | totma
# Processing Record 26 of Set 8 | ampanihy
# Processing Record 27 of Set 8 | airai
# Processing Record 28 of Set 8 | ponta delgada
# Processing Record 29 of Set 8 | qandala
# Processing Record 30 of Set 8 | lompoc
# Processing Record 31 of Set 8 | comodoro rivadavia
# Processing Record 32 of Set 8 | vangaindrano
# Processing Record 33 of Set 8 | walvis bay
# Processing Record 34 of Set 8 | antalaha
# Processing Record 35 of Set 8 | egvekinot
# Processing Record 36 of Set 8 | shingu
# Processing Record 37 of Set 8 | kollumerland
# City not found. Skipping...
# Processing Record 38 of Set 8 | moroni
# Processing Record 39 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 8 | santa cruz
# Processing Record 41 of Set 8 | zhangye
# Processing Record 42 of Set 8 | slave lake
# Processing Record 43 of Set 8 | basse
# Processing Record 44 of Set 8 | alanya
# Processing Record 45 of Set 8 | manado
# Processing Record 46 of Set 8 | ligayan
# Processing Record 47 of Set 8 | didwana
# Processing Record 48 of Set 8 | chicama
# Processing Record 49 of Set 8 | wajir
# Processing Record 50 of Set 8 | latung
# Processing Record 1 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 9 | itupiranga
# Processing Record 3 of Set 9 | porto nacional
# Processing Record 4 of Set 9 | cap malheureux
# Processing Record 5 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 6 of Set 9 | emerald
# Processing Record 7 of Set 9 | leh
# Processing Record 8 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 9 | cumra
# Processing Record 10 of Set 9 | malacky
# Processing Record 11 of Set 9 | priamurskiy
# Processing Record 12 of Set 9 | port hawkesbury
# Processing Record 13 of Set 9 | suihua
# Processing Record 14 of Set 9 | llanes
# Processing Record 15 of Set 9 | manokwari
# Processing Record 16 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 9 | nsanje
# Processing Record 18 of Set 9 | namibe
# Processing Record 19 of Set 9 | salalah
# Processing Record 20 of Set 9 | nikolayevsk-na-amure
# Processing Record 21 of Set 9 | kieta
# Processing Record 22 of Set 9 | nhulunbuy
# Processing Record 23 of Set 9 | ust-ishim
# Processing Record 24 of Set 9 | simbahan
# Processing Record 25 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 26 of Set 9 | muriti
# Processing Record 27 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 9 | udachnyy
# Processing Record 29 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 30 of Set 9 | ambilobe
# Processing Record 31 of Set 9 | college
# Processing Record 32 of Set 9 | vila franca do campo
# Processing Record 33 of Set 9 | bankja
# City not found. Skipping...
# Processing Record 34 of Set 9 | constitucion
# Processing Record 35 of Set 9 | algiers
# Processing Record 36 of Set 9 | mountain home
# Processing Record 37 of Set 9 | bandarbeyla
# Processing Record 38 of Set 9 | kitimat
# Processing Record 39 of Set 9 | turinskaya sloboda
# Processing Record 40 of Set 9 | havre-saint-pierre
# Processing Record 41 of Set 9 | quarai
# Processing Record 42 of Set 9 | trinidad
# Processing Record 43 of Set 9 | lima
# Processing Record 44 of Set 9 | fairbanks
# Processing Record 45 of Set 9 | beira
# Processing Record 46 of Set 9 | halifax
# Processing Record 47 of Set 9 | kokstad
# Processing Record 48 of Set 9 | champerico
# Processing Record 49 of Set 9 | codrington
# Processing Record 50 of Set 9 | sola
# Processing Record 1 of Set 10 | tres arroyos
# Processing Record 2 of Set 10 | koumac
# Processing Record 3 of Set 10 | blagoyevo
# Processing Record 4 of Set 10 | inhambane
# Processing Record 5 of Set 10 | tromso
# Processing Record 6 of Set 10 | komsomolskiy
# Processing Record 7 of Set 10 | kigorobya
# Processing Record 8 of Set 10 | najran
# Processing Record 9 of Set 10 | mount isa
# Processing Record 10 of Set 10 | marfino
# Processing Record 11 of Set 10 | goderich
# Processing Record 12 of Set 10 | eureka
# Processing Record 13 of Set 10 | malanje
# Processing Record 14 of Set 10 | tagab
# Processing Record 15 of Set 10 | muli
# Processing Record 16 of Set 10 | hofn
# Processing Record 17 of Set 10 | saint-georges
# Processing Record 18 of Set 10 | sao jose da coroa grande
# Processing Record 19 of Set 10 | doka
# Processing Record 20 of Set 10 | cartagena
# Processing Record 21 of Set 10 | vostok
# Processing Record 22 of Set 10 | patti
# Processing Record 23 of Set 10 | omboue
# Processing Record 24 of Set 10 | xichang
# Processing Record 25 of Set 10 | popondetta
# Processing Record 26 of Set 10 | siniscola
# Processing Record 27 of Set 10 | andenes
# Processing Record 28 of Set 10 | canita
# Processing Record 29 of Set 10 | swellendam
# Processing Record 30 of Set 10 | jalingo
# Processing Record 31 of Set 10 | santa barbara
# Processing Record 32 of Set 10 | rocha
# Processing Record 33 of Set 10 | barhi
# Processing Record 34 of Set 10 | mandalgovi
# Processing Record 35 of Set 10 | ballina
# Processing Record 36 of Set 10 | port moresby
# Processing Record 37 of Set 10 | necochea
# Processing Record 38 of Set 10 | zyryanka
# Processing Record 39 of Set 10 | cockburn town
# Processing Record 40 of Set 10 | ola
# Processing Record 41 of Set 10 | nabire
# Processing Record 42 of Set 10 | gizo
# Processing Record 43 of Set 10 | wencheng
# Processing Record 44 of Set 10 | chor
# Processing Record 45 of Set 10 | faya
# Processing Record 46 of Set 10 | karabash
# Processing Record 47 of Set 10 | suba
# Processing Record 48 of Set 10 | caravelas
# Processing Record 49 of Set 10 | haverfordwest
# Processing Record 50 of Set 10 | zapolyarnyy
# Processing Record 1 of Set 11 | tougue
# Processing Record 2 of Set 11 | thinadhoo
# Processing Record 3 of Set 11 | soyo
# Processing Record 4 of Set 11 | vestmannaeyjar
# Processing Record 5 of Set 11 | bagdarin
# Processing Record 6 of Set 11 | fortuna
# Processing Record 7 of Set 11 | mizdah
# Processing Record 8 of Set 11 | san jeronimo
# Processing Record 9 of Set 11 | ayotzintepec
# Processing Record 10 of Set 11 | poum
# Processing Record 11 of Set 11 | gonaives
# Processing Record 12 of Set 11 | vanimo
# Processing Record 13 of Set 11 | george town
# Processing Record 14 of Set 11 | san policarpo
# Processing Record 15 of Set 11 | putla
# City not found. Skipping...
# Processing Record 16 of Set 11 | shimoda
# Processing Record 17 of Set 11 | tecozautla
# Processing Record 18 of Set 11 | parang
# Processing Record 19 of Set 11 | constantine
# Processing Record 20 of Set 11 | camana
# Processing Record 21 of Set 11 | sur
# Processing Record 22 of Set 11 | torbay
# Processing Record 23 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 11 | aksarka
# Processing Record 25 of Set 11 | yaan
# Processing Record 26 of Set 11 | mizan teferi
# Processing Record 27 of Set 11 | dunedin
# Processing Record 28 of Set 11 | rio grande city
# Processing Record 29 of Set 11 | susangerd
# Processing Record 30 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 31 of Set 11 | pisco
# Processing Record 32 of Set 11 | puerto pinasco
# City not found. Skipping...
# Processing Record 33 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 34 of Set 11 | kalianget
# Processing Record 35 of Set 11 | maputo
# Processing Record 36 of Set 11 | hami
# Processing Record 37 of Set 11 | honningsvag
# Processing Record 38 of Set 11 | sitka
# Processing Record 39 of Set 11 | black river
# Processing Record 40 of Set 11 | matagami
# Processing Record 41 of Set 11 | bethanien
# Processing Record 42 of Set 11 | riohacha
# Processing Record 43 of Set 11 | papara
# Processing Record 44 of Set 11 | rapid valley
# Processing Record 45 of Set 11 | sarangani
# Processing Record 46 of Set 11 | felipe carrillo puerto
# Processing Record 47 of Set 11 | korla
# Processing Record 48 of Set 11 | rensvik
# Processing Record 49 of Set 11 | port lincoln
# Processing Record 50 of Set 11 | heihe
# Processing Record 1 of Set 12 | askiz
# Processing Record 2 of Set 12 | lively
# Processing Record 3 of Set 12 | hendijan
# City not found. Skipping...
# Processing Record 4 of Set 12 | kloulklubed
# Processing Record 5 of Set 12 | kannangad
# Processing Record 6 of Set 12 | sibu
# Processing Record 7 of Set 12 | santa cruz de las flores
# Processing Record 8 of Set 12 | tomatlan
# Processing Record 9 of Set 12 | naze
# Processing Record 10 of Set 12 | luderitz
# Processing Record 11 of Set 12 | royan
# Processing Record 12 of Set 12 | nanortalik
# Processing Record 13 of Set 12 | atar
# Processing Record 14 of Set 12 | chernyshevskiy
# Processing Record 15 of Set 12 | shilong
# Processing Record 16 of Set 12 | ust-ilimsk
# Processing Record 17 of Set 12 | sanming
# Processing Record 18 of Set 12 | jalu
# Processing Record 19 of Set 12 | noumea
# Processing Record 20 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 12 | nyakahanga
# Processing Record 22 of Set 12 | puerto escondido
# Processing Record 23 of Set 12 | namatanai
# Processing Record 24 of Set 12 | huejuquilla el alto
# Processing Record 25 of Set 12 | puerto ayacucho
# Processing Record 26 of Set 12 | biltine
# Processing Record 27 of Set 12 | sovetskoye
# Processing Record 28 of Set 12 | benjamin constant
# Processing Record 29 of Set 12 | puerto cabezas
# Processing Record 30 of Set 12 | sant julia de loria
# Processing Record 31 of Set 12 | santa rosa
# Processing Record 32 of Set 12 | dioknisi
# Processing Record 33 of Set 12 | vilyuysk
# Processing Record 34 of Set 12 | petersburg
# Processing Record 35 of Set 12 | pacific grove
# Processing Record 36 of Set 12 | alice springs
# Processing Record 37 of Set 12 | bolshiye uki
# City not found. Skipping...
# Processing Record 38 of Set 12 | meulaboh
# Processing Record 39 of Set 12 | huarmey
# Processing Record 40 of Set 12 | assomada
# Processing Record 41 of Set 12 | poronaysk
# Processing Record 42 of Set 12 | alekseyevsk
# Processing Record 43 of Set 12 | banda aceh
# Processing Record 44 of Set 12 | darnah
# Processing Record 45 of Set 12 | bauchi
# Processing Record 46 of Set 12 | canton
# Processing Record 47 of Set 12 | gondar
# Processing Record 48 of Set 12 | carballo
# Processing Record 49 of Set 12 | whitianga
# Processing Record 50 of Set 12 | carahue
# Processing Record 1 of Set 13 | asau
# Processing Record 2 of Set 13 | bambanglipuro
# Processing Record 3 of Set 13 | adrar
# Processing Record 4 of Set 13 | olinda
# Processing Record 5 of Set 13 | varhaug
# Processing Record 6 of Set 13 | ayorou
# Processing Record 7 of Set 13 | katsuyama
# Processing Record 8 of Set 13 | iztapa
# Processing Record 9 of Set 13 | srednekolymsk
# Processing Record 10 of Set 13 | kalundborg
# Processing Record 11 of Set 13 | yerbogachen
# Processing Record 12 of Set 13 | verkhnechusovskiye gorodki
# Processing Record 13 of Set 13 | jining
# Processing Record 14 of Set 13 | qaqortoq
# Processing Record 15 of Set 13 | srandakan
# Processing Record 16 of Set 13 | coari
# Processing Record 17 of Set 13 | sioux lookout
# Processing Record 18 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 13 | entre rios
# Processing Record 20 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 13 | vaasa
# Processing Record 22 of Set 13 | ambovombe
# Processing Record 23 of Set 13 | lakhimpur
# Processing Record 24 of Set 13 | namie
# Processing Record 25 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 13 | kudahuvadhoo
# Processing Record 27 of Set 13 | bilibino
# Processing Record 28 of Set 13 | chester
# Processing Record 29 of Set 13 | aleksandrovsk-sakhalinskiy
# Processing Record 30 of Set 13 | taksimo
# Processing Record 31 of Set 13 | vikulovo
# Processing Record 32 of Set 13 | minnedosa
# Processing Record 33 of Set 13 | jaciara
# Processing Record 34 of Set 13 | mnichovo hradiste
# Processing Record 35 of Set 13 | angra
# City not found. Skipping...
# Processing Record 36 of Set 13 | nichinan
# Processing Record 37 of Set 13 | brooks
# Processing Record 38 of Set 13 | camargo
# Processing Record 39 of Set 13 | lahr
# Processing Record 40 of Set 13 | omsukchan
# Processing Record 41 of Set 13 | trairi
# Processing Record 42 of Set 13 | kommunar
# Processing Record 43 of Set 13 | moyale
# Processing Record 44 of Set 13 | lata
# Processing Record 45 of Set 13 | raudeberg
# Processing Record 46 of Set 13 | san julian
# Processing Record 47 of Set 13 | alekseyevka
# Processing Record 48 of Set 13 | matane
# Processing Record 49 of Set 13 | mayo
# Processing Record 50 of Set 13 | maine-soroa
# Processing Record 1 of Set 14 | pithoro
# Processing Record 2 of Set 14 | frankfort
# Processing Record 3 of Set 14 | durango
# Processing Record 4 of Set 14 | jaca
# Processing Record 5 of Set 14 | kjollefjord
# Processing Record 6 of Set 14 | kaili
# Processing Record 7 of Set 14 | baltasi
# Processing Record 8 of Set 14 | gazanjyk
# Processing Record 9 of Set 14 | dauphin
# Processing Record 10 of Set 14 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 11 of Set 14 | saldanha
# Processing Record 12 of Set 14 | araioses
# Processing Record 13 of Set 14 | moose factory
# Processing Record 14 of Set 14 | salinopolis
# Processing Record 15 of Set 14 | teguldet
# Processing Record 16 of Set 14 | loding
# Processing Record 17 of Set 14 | casablanca
# Processing Record 18 of Set 14 | rabaul
# Processing Record 19 of Set 14 | pinawa
# Processing Record 20 of Set 14 | klyuchi
# Processing Record 21 of Set 14 | virginia beach
# Processing Record 22 of Set 14 | palmer
# Processing Record 23 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 14 | kolokani
# Processing Record 25 of Set 14 | kovdor
# Processing Record 26 of Set 14 | ritchie
# Processing Record 27 of Set 14 | inuvik
# Processing Record 28 of Set 14 | touros
# Processing Record 29 of Set 14 | binzhou
# Processing Record 30 of Set 14 | leshukonskoye
# Processing Record 31 of Set 14 | ketchikan
# Processing Record 32 of Set 14 | carlsbad
# Processing Record 33 of Set 14 | saint-paul
# Processing Record 34 of Set 14 | dno
# Processing Record 35 of Set 14 | mgandu
# Processing Record 36 of Set 14 | contamana
# Processing Record 37 of Set 14 | wuan
# Processing Record 38 of Set 14 | podor
# Processing Record 39 of Set 14 | puerto madryn
# Processing Record 40 of Set 14 | xapuri
# Processing Record 41 of Set 14 | normandin
# Processing Record 42 of Set 14 | teguise
# Processing Record 43 of Set 14 | bereda
# Processing Record 44 of Set 14 | bicholim
# Processing Record 45 of Set 14 | bubaque
# Processing Record 46 of Set 14 | playas
# Processing Record 47 of Set 14 | novoderevyankovskaya
# Processing Record 48 of Set 14 | hauterive
# Processing Record 49 of Set 14 | acapulco
# Processing Record 50 of Set 14 | buala
# Processing Record 1 of Set 15 | karakol
# Processing Record 2 of Set 15 | san cristobal
# Processing Record 3 of Set 15 | pemberton
# Processing Record 4 of Set 15 | senador jose porfirio
# Processing Record 5 of Set 15 | mercedes
# Processing Record 6 of Set 15 | tefe
# Processing Record 7 of Set 15 | chapais
# Processing Record 8 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 9 of Set 15 | luganville
# Processing Record 10 of Set 15 | prabumulih
# Processing Record 11 of Set 15 | tutoia
# Processing Record 12 of Set 15 | malanville
# Processing Record 13 of Set 15 | slonim
# Processing Record 14 of Set 15 | rawah
# Processing Record 15 of Set 15 | bemidji
# Processing Record 16 of Set 15 | ust-kuyga
# Processing Record 17 of Set 15 | kalavrita
# City not found. Skipping...
# Processing Record 18 of Set 15 | aksarayskiy
# Processing Record 19 of Set 15 | dergachi
# Processing Record 20 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 21 of Set 15 | tadine
# Processing Record 22 of Set 15 | wainwright
# Processing Record 23 of Set 15 | uruzgan
# Processing Record 24 of Set 15 | ayan
# Processing Record 25 of Set 15 | puri
# Processing Record 26 of Set 15 | sabang
# Processing Record 27 of Set 15 | san vicente
# Processing Record 28 of Set 15 | antofagasta
# Processing Record 29 of Set 15 | sorland
# Processing Record 30 of Set 15 | macon
# Processing Record 31 of Set 15 | nizhniy ingash
# Processing Record 32 of Set 15 | severomuysk
# Processing Record 33 of Set 15 | boysun
# Processing Record 34 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 35 of Set 15 | calhoun
# Processing Record 36 of Set 15 | turukhansk
# Processing Record 37 of Set 15 | rio cuarto
# Processing Record 38 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 15 | mogadishu
# Processing Record 40 of Set 15 | zhigansk
# Processing Record 41 of Set 15 | escalerillas
# Processing Record 42 of Set 15 | la ronge
# Processing Record 43 of Set 15 | yanam
# Processing Record 44 of Set 15 | ewo
# Processing Record 45 of Set 15 | tchollire
# Processing Record 46 of Set 15 | nanga eboko
# Processing Record 47 of Set 15 | keelung
# Processing Record 48 of Set 15 | flin flon
# Processing Record 49 of Set 15 | gaoua
# Processing Record 50 of Set 15 | dubti
# Processing Record 1 of Set 16 | abu samrah
# Processing Record 2 of Set 16 | moranbah
# Processing Record 3 of Set 16 | svetlogorsk
# Processing Record 4 of Set 16 | iralaya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 696

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Wake Forest  35.9799  -78.5097     44.91        64           0
# 1  Marsh Harbour  26.5412  -77.0636     78.84        72           1
# 2        Atbasar  51.8000   68.3333     33.71        98         100
# 3        Chifeng  42.2683  118.9636     29.07        72           3
# 4      Hithadhoo  -0.6000   73.0833     81.16        77         100
# 5         Barrow  71.2906 -156.7887     17.62        73         100
# 6     Chokurdakh  70.6333  147.9167    -18.67        97         100
# 7         Gallup  35.5281 -108.7426     43.56        35         100
# 8     Georgetown   5.4112  100.3354     80.53        92          20
# 9          Kapaa  22.0752 -159.3190     82.38        70          40
#
#    Wind Speed Country
# 0        5.99      US
# 1       10.27      BS
# 2       23.31      KZ
# 3        5.30      CN
# 4       13.20      MV
# 5        9.22      US
# 6        7.34      RU
# 7       14.97      US
# 8        5.75      MY
# 9       16.11      US

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:


# Recreate the DataFrame by using the new column order
city_data_df.loc[:, ["City","Country","Lat","Lng","Max Temp", "Humidity","Cloudiness","Wind Speed"]]

# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Wake Forest  35.9799  -78.5097     44.91        64           0
# 1  Marsh Harbour  26.5412  -77.0636     78.84        72           1
# 2        Atbasar  51.8000   68.3333     33.71        98         100
# 3        Chifeng  42.2683  118.9636     29.07        72           3
# 4      Hithadhoo  -0.6000   73.0833     81.16        77         100
# 5         Barrow  71.2906 -156.7887     17.62        73         100
# 6     Chokurdakh  70.6333  147.9167    -18.67        97         100
# 7         Gallup  35.5281 -108.7426     43.56        35         100
# 8     Georgetown   5.4112  100.3354     80.53        92          20
# 9          Kapaa  22.0752 -159.3190     82.38        70          40
#
#    Wind Speed Country
# 0        5.99      US
# 1       10.27      BS
# 2       23.31      KZ
# 3        5.30      CN
# 4       13.20      MV
# 5        9.22      US
# 6        7.34      RU
# 7       14.97      US
# 8        5.75      MY
# 9       16.11      US

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
